# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Criando um objeto Service para o ChromeDriver
service = Service('D:/nichoOnline/chromedriver.exe')

# Iniciando o WebDriver com o serviço configurado
driver = webdriver.Chrome(service=service)

# Acessar uma página web (exemplo: Google)
driver.get('https://www.google.com')

# Fechar o navegador após a navegação
driver.quit()

# %%
X =1

# %%
import requests
from bs4 import BeautifulSoup

# URL da página que você deseja acessar
url = "https://sgf-sp.bracell.com/sgf/Modulos/Transporte/TraOrdemTransporteRodoviarioFrm.aspx?cdprocesso=4&cdfuncao=4824"

# Cabeçalhos da requisição
headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,es;q=0.6",
    "Connection": "keep-alive",
    "Referer": "https://sgf-sp.bracell.com/",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
}

# Cookies completos
cookies = {
    "ASP.NET_SessionId": "bpboxa0jcy5trg1v1ey0otz2",
    "{Infra.ConnectionString.Name}": "p_sgf",
    ".SGF": ""
}


# Fazendo a requisição GET com os cookies
response = requests.get(url, headers=headers, cookies=cookies)

# Verificando se a requisição foi bem-sucedida
if response.status_code == 200:
    print("Requisição bem-sucedida!")
    # Parsear o conteúdo da página com BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extraindo as informações desejadas
    fornecedor = soup.find('span', id="ctl48_ctl01_ctl03_CdFornecedorEquipamentoDESC").text
    projeto = soup.find('span', id="ctl48_ctl01_ctl03_CdProjetoDESC").text
    documento = soup.find('span', id="ctl48_ctl01_ctl03_CdDocumentoDESC").text
    equipamento = soup.find('span', id="ctl48_ctl01_ctl03_CdEquipamentoDESC").text
    tipo_conjunto = soup.find('span', id="ctl48_ctl01_ctl03_CdTipoConjuntoDESC").text
    situacao = soup.find('span', id="ctl48_ctl01_ctl03_TipSituacaoDESC").text

    # Exibindo as informações capturadas
    print("Fornecedor:", fornecedor)
    print("Projeto:", projeto)
    print("Documento:", documento)
    print("Equipamento:", equipamento)
    print("Tipo de Conjunto:", tipo_conjunto)
    print("Situação:", situacao)
else:
    print(f"Erro ao acessar a página: {response.status_code}")
# Out:
# Requisição bem-sucedida!
# Fornecedor: EXPRESSO NEPOMUCENO S/A
# Projeto: SANTO ANTÔNIO
# Documento:
# Equipamento: GDT8F11
# Tipo de Conjunto: TRITREM
# Situação: Gerada

# %%
import requests
from bs4 import BeautifulSoup
import time

# Função para capturar as informações em múltiplas linhas
def capturar_informacoes():

    # URL da página que você deseja acessar
    url = "https://sgf-sp.bracell.com/sgf/Modulos/Transporte/TraOrdemTransporteRodoviarioFrm.aspx?cdprocesso=4&cdfuncao=4824"

    # Cabeçalhos da requisição
    headers = {
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
        "Accept-Encoding": "gzip, deflate, br, zstd",
        "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,es;q=0.6",
        "Connection": "keep-alive",
        "Referer": "https://sgf-sp.bracell.com/",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
    }

    # Cookies completos
    cookies = {
        "ASP.NET_SessionId": "bpboxa0jcy5trg1v1ey0otz2",
        "{Infra.ConnectionString.Name}": "p_sgf",
        ".SGF": ""
    }

    # Fazendo a requisição GET com os cookies
    response = requests.get(url, headers=headers, cookies=cookies)

    # Verificando se a requisição foi bem-sucedida
    if response.status_code == 200:
        print("Requisição bem-sucedida!")
        # Parsear o conteúdo da página com BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Loop para capturar informações de várias linhas (ctl03 a ctl12)
        for i in range(3, 13):  # ctl03 até ctl12
            try:
                fornecedor = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdFornecedorEquipamentoDESC")
                projeto = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdProjetoDESC")
                documento = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdDocumentoDESC")
                equipamento = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdEquipamentoDESC")
                tipo_conjunto = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdTipoConjuntoDESC")
                situacao = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_TipSituacaoDESC")

                # Verificar se todos os elementos foram encontrados
                if not all([fornecedor, projeto, documento, equipamento, tipo_conjunto, situacao]):
                    print(f"Linha {i-2}: Informações incompletas, alguns elementos não foram encontrados.")
                    print("-" * 50)
                    continue

                fornecedor = fornecedor.text
                projeto = projeto.text
                documento = documento.text
                equipamento = equipamento.text
                tipo_conjunto = tipo_conjunto.text
                situacao = situacao.text

                # Logica para decisão baseada na situação
                if situacao == "Circulacao":
                    # Processar o vale-pedágio (lógica de preenchimento do vale-pedágio)
                    print(f"Linha {i-2}: Preencher Vale-Pedágio")
                    print("Fornecedor:", fornecedor)
                    print("Projeto:", projeto)
                    print("Documento:", documento)
                    print("Equipamento:", equipamento)
                    print("Tipo de Conjunto:", tipo_conjunto)
                    print("Situação:", situacao)
                    print("-" * 50)
                
                elif situacao == "Gerada":
                    # Deixar para a próxima iteração
                    print(f"Linha {i-2}: Situação GERADA, tentar novamente na próxima iteração.")
                    print("-" * 50)
                
                elif situacao == "Finalizada":
                    # Descartar esse caminhão
                    print(f"Linha {i-2}: Situação FINALIZADA, descartando este caminhão.")
                    print("-" * 50)

            except AttributeError as e:
                # Se não encontrar o ID, passa para a próxima linha
                print(f"Linha {i-2}: Erro ao capturar informações: {e}")
                print("-" * 50)
    else:
        print(f"Erro ao acessar a página: {response.status_code}")


capturar_informacoes()
# Out:
# Requisição bem-sucedida!
# Linha 1: Situação GERADA, tentar novamente na próxima iteração.
# --------------------------------------------------
# Linha 2: Preencher Vale-Pedágio
# Fornecedor: JSL SA
# Projeto: SÃO MANOEL GLEBA A - CPG
# Documento: 292790
# Equipamento: JBU9B60
# Tipo de Conjunto: TRITREM
# Situação: Circulacao
# --------------------------------------------------
# Linha 3: Preencher Vale-Pedágio
# Fornecedor: CARGO POLO COMERCIO, LOGISTICA E TRANSPORTE
# Projeto: SÃO MANOEL GLEBA A - CPG
# Documento: 292788
# Equipamento: TIO6E45
# Tipo de Conjunto: TRITREM
# Situação: Circulacao
# --------------------------------------------------
# Linha 4: Preencher Vale-Pedágio
# Fornecedor: CARGO POLO COMERCIO, LOGISTICA E TRANSPORTE
# Projeto: SÃO MANOEL GLEBA A - CPG
# Documento: 292789
# Equipamento: FVF0F64
# Tipo de Conjunto: TRITREM
# Situação: Circulacao
# --------------------------------------------------
# Linha 5: Preencher Vale-Pedágio
# ...

# %%
import requests
from bs4 import BeautifulSoup
import time

# Função para capturar as informações em múltiplas linhas
def capturar_informacoes():

    # URL da página que você deseja acessar
    url = "https://sgf-sp.bracell.com/sgf/Modulos/Transporte/TraOrdemTransporteRodoviarioFrm.aspx?cdprocesso=4&cdfuncao=4824"

    # Cabeçalhos da requisição
    headers = {
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
        "Accept-Encoding": "gzip, deflate, br, zstd",
        "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,es;q=0.6",
        "Connection": "keep-alive",
        "Referer": "https://sgf-sp.bracell.com/",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
    }

    # Cookies completos
    cookies = {
        "ASP.NET_SessionId": "bpboxa0jcy5trg1v1ey0otz2",
        "{Infra.ConnectionString.Name}": "p_sgf",
        ".SGF": ""
    }

    # Fazendo a requisição GET com os cookies
    response = requests.get(url, headers=headers, cookies=cookies)

    # Verificando se a requisição foi bem-sucedida
    if response.status_code == 200:
        print("Requisição bem-sucedida!")
        # Parsear o conteúdo da página com BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Loop para capturar informações de várias linhas (ctl03 a ctl12)
        for i in range(3, 13):  # ctl03 até ctl12
            try:
                fornecedor = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdFornecedorEquipamentoDESC")
                projeto = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdProjetoDESC")
                documento = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdDocumentoDESC")
                equipamento = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdEquipamentoDESC")
                tipo_conjunto = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdTipoConjuntoDESC")
                situacao = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_TipSituacaoDESC")

                # Verificar se todos os elementos foram encontrados
                if not all([fornecedor, projeto, documento, equipamento, tipo_conjunto, situacao]):
                    print(f"Linha {i-2}: Informações incompletas, alguns elementos não foram encontrados.")
                    print("-" * 50)
                    continue

                fornecedor = fornecedor.text
                projeto = projeto.text
                documento = documento.text
                equipamento = equipamento.text
                tipo_conjunto = tipo_conjunto.text
                situacao = situacao.text

                # Lógica de filtragem de projetos e fornecedores
                if projeto in ["SÃO MANOEL GLEBA A - CPG", "SANTO ANTÔNIO", "NOSSA SENHORA APARECIDA XV"]:
                    print(f"Linha {i-2}: Projeto '{projeto}' ignorado.")
                    continue

                if fornecedor == "CARGO POLO COMERCIO, LOGISTICA E TRANSPORTE":
                    if tipo_conjunto == "Cargo Polo (5 eixos ida)" or tipo_conjunto == "Cargo Polo (6 eixos ida)":
                        print(f"Linha {i-2}: Fornecedor '{fornecedor}' com {tipo_conjunto} ignorado.")
                        continue

                # Logica para decisão baseada na situação
                if situacao == "Circulacao":
                    # Processar o vale-pedágio (lógica de preenchimento do vale-pedágio)
                    print(f"Linha {i-2}: Preencher Vale-Pedágio")
                    print("Fornecedor:", fornecedor)
                    print("Projeto:", projeto)
                    print("Documento:", documento)
                    print("Equipamento:", equipamento)
                    print("Tipo de Conjunto:", tipo_conjunto)
                    print("Situação:", situacao)
                    print("-" * 50)
                
                elif situacao == "Gerada":
                    # Deixar para a próxima iteração
                    print(f"Linha {i-2}: Situação GERADA, tentar novamente na próxima iteração.")
                    print("-" * 50)
                
                elif situacao == "Finalizada":
                    # Descartar esse caminhão
                    print(f"Linha {i-2}: Situação FINALIZADA, descartando este caminhão.")
                    print("-" * 50)

            except AttributeError as e:
                # Se não encontrar o ID, passa para a próxima linha
                print(f"Linha {i-2}: Erro ao capturar informações: {e}")
                print("-" * 50)
    else:
        print(f"Erro ao acessar a página: {response.status_code}")


# Executar a função de captura de informações
capturar_informacoes()
# Out:
# Requisição bem-sucedida!
# Linha 1: Projeto 'SÃO MANOEL GLEBA A - CPG' ignorado.
# Linha 2: Projeto 'SÃO MANOEL GLEBA A - CPG' ignorado.
# Linha 3: Projeto 'SÃO MANOEL GLEBA A - CPG' ignorado.
# Linha 4: Projeto 'SÃO MANOEL GLEBA A - CPG' ignorado.
# Linha 5: Projeto 'NOSSA SENHORA APARECIDA XV' ignorado.
# Linha 6: Projeto 'NOSSA SENHORA APARECIDA XV' ignorado.
# Linha 7: Projeto 'SÃO MANOEL GLEBA A - CPG' ignorado.
# Linha 8: Projeto 'SÃO MANOEL GLEBA A - CPG' ignorado.
# Linha 9: Projeto 'SÃO MANOEL GLEBA A - CPG' ignorado.
# Linha 10: Projeto 'SÃO MANOEL GLEBA A - CPG' ignorado.

# %%
import requests
from bs4 import BeautifulSoup

    # URL da página que você deseja acessar
url = "https://sgf-sp.bracell.com/sgf/Modulos/Transporte/TraOrdemTransporteRodoviarioFrm.aspx?cdprocesso=48&cdfuncao=4824"

# Cabeçalhos da requisição (mantendo os valores padrão, você pode ajustar conforme necessário)
headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,es;q=0.6",
    "Connection": "keep-alive",
    "Host": "sgf-sp.bracell.com",
    "Referer": "https://sgf-sp.bracell.com/",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
}

# Cookies copiados da sua sessão
cookies = {
    "ASP.NET_SessionId": "jzhu52kybr3vp5k2bbvzy3se",
    "{Infra.ConnectionString.Name}": "p_sgf",
    ".SGF": ""
}

# Fazendo a requisição GET para obter o conteúdo inicial da página
response = requests.get(url, headers=headers, cookies=cookies)

# Verificando se a requisição foi bem-sucedida
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Capturando os valores de __VIEWSTATE e __EVENTVALIDATION
    viewstate = soup.find("input", {"id": "__VIEWSTATE"})['value']
    eventvalidation = soup.find("input", {"id": "__EVENTVALIDATION"})['value']
    
    # Preparar os dados para envio em uma requisição POST
    data = {
        "__VIEWSTATE": viewstate,
        "__EVENTVALIDATION": eventvalidation,
        # Adicione outros dados do formulário aqui, se necessário
    }

    # Fazer uma requisição POST para a página, enviando os dados do formulário
    post_response = requests.post(url, headers=headers, cookies=cookies, data=data)

    if post_response.status_code == 200:
        print("POST bem-sucedido!")
        # Verifique se o conteúdo retornado é o esperado
        print(post_response.text)
    else:
        print(f"Erro no POST: {post_response.status_code}")
else:
    print(f"Erro ao acessar a página: {response.status_code}")
# Out:
# POST bem-sucedido!
#
#
# <!doctype html>
# <html>
# <head id="Head1"><title>
# 	SGF
# </title>
#     <style type="text/css">
#         .btnEnvio {
#                 background:url('UIEgf/Images/imagens_login/bt_entrar.jpg') no-repeat;
#                 text-align:center;
#                 font-size:11.5px;
#                 font-weight:bold;
#                 color:white;
#                 border:none !important;
#                 height:25px !important;
#                 width:60px !important;
#                 text-transform:uppercase;
#                 cursor:pointer;
#                 margin-top:6px;
#                 margin-bottom:4px;
#             }
#
#             #divEsqueciSenha span
#             {
#                 text-align:right;
#             }
#     </style>
#         <script src="UIEgf/Scripts/Graficos/jquery.min.js"></script>
#         <script src="UI/Scripts/jquery.blockUI.js"></script>
# </head>
# ...

# %%
import requests
from lxml import etree
from datetime import datetime, timedelta
import time
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import streamlit as st
# Função para remover namespaces do XML
def remove_namespaces(tree):
    """Remove namespaces de um elemento XML e seus filhos."""
    for elem in tree.getiterator():
        elem.tag = elem.tag.split('}')[-1]
    etree.cleanup_namespaces(tree)
    return tree

# Função para autenticar o usuário
def autenticar_usuario():
    url = 'https://apphom.viafacil.com.br/wsvp/ValePedagio'
    headers = {
        'Content-Type': 'text/xml; charset=utf-8',
        'SOAPAction': 'autenticarUsuario'
    }
    envelope = etree.Element('{http://schemas.xmlsoap.org/soap/envelope/}Envelope',
                            nsmap={
                                'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
                                'xsd': 'http://www.w3.org/2001/XMLSchema',
                                'soapenv': 'http://schemas.xmlsoap.org/soap/envelope/',
                                'cgmp': 'http://cgmp.com'
                            })
    body = etree.SubElement(envelope, '{http://schemas.xmlsoap.org/soap/envelope/}Body')
    autenticar_usuario = etree.SubElement(body, '{http://cgmp.com}autenticarUsuario',
                                        attrib={'{http://schemas.xmlsoap.org/soap/envelope/}encodingStyle': 'http://schemas.xmlsoap.org/soap/encoding/'})
    
    codigodeacesso = etree.SubElement(autenticar_usuario, 'codigodeacesso', attrib={etree.QName('xsi', 'type'): 'xsd:string'})
    codigodeacesso.text = '53943098000187'
    
    login = etree.SubElement(autenticar_usuario, 'login', attrib={etree.QName('xsi', 'type'): 'xsd:string'})
    login.text = 'ADMINISTRADOR'
    
    senha = etree.SubElement(autenticar_usuario, 'senha', attrib={etree.QName('xsi', 'type'): 'xsd:string'})
    senha.text = 'grupostp'
    
    soap_request = etree.tostring(envelope, pretty_print=True, xml_declaration=True, encoding='UTF-8')
    
    try:
        response = requests.post(url, data=soap_request, headers=headers)
        response.raise_for_status()

        # Remover namespaces
        response_content = etree.fromstring(response.content)
        response_content = remove_namespaces(response_content)

        # Verifica o elemento 'autenticarUsuarioReturn'
        autenticar_usuario_return = response_content.find('.//autenticarUsuarioReturn')
        if autenticar_usuario_return is not None:
            sessao_element = autenticar_usuario_return.find('.//sessao')
            if sessao_element is not None:
                return sessao_element.text
        return None
    except requests.exceptions.RequestException as e:
        print(f"Erro na requisição SOAP: {e}")
        return None

# Função para processar a viagem
def processar_viagem(placa, fazenda, conjunto):
    # Autentica o usuário e obtém a sessão
    sessao = autenticar_usuario()
    if not sessao:
        print("Erro ao autenticar o usuário. Verifique as credenciais e tente novamente.")
        return

    # Definir as datas de vigência
    inicioVigencia = datetime.today().strftime('%Y-%m-%d')
    fimVigencia = (datetime.today() + timedelta(days=5)).strftime('%Y-%m-%d')

    # Definir os eixos com base no tipo de conjunto selecionado
    if conjunto == 'Bitrem':
        nEixosIda = 4
        nEixosVolta = 7
    elif conjunto == 'Tritrem':
        nEixosIda = 6
        nEixosVolta = 9
    elif conjunto == 'Cargo Polo (5 eixos ida)':
        nEixosIda = 5
        nEixosVolta = 9
    elif conjunto == 'Cargo Polo (6 eixos ida)':
        nEixosIda = 6
        nEixosVolta = 9
    else:
        print("Tipo de conjunto não reconhecido.")
        return

    rotas = [
        {'ida': f'FAZ {fazenda} - IDA', 'volta': f'FAZ {fazenda} - VOLTA'},
    ]

    for rota in rotas:
        numero_viagem_ida = comprar_viagem(sessao, rota['ida'], placa, nEixosIda, inicioVigencia, fimVigencia)
        if numero_viagem_ida:
            imprimir_recibo(sessao, numero_viagem_ida, True)
        else:
            print(f"Falha na compra da viagem de ida para {rota['ida']}")

        numero_viagem_volta = comprar_viagem(sessao, rota['volta'], placa, nEixosVolta, inicioVigencia, fimVigencia)
        if numero_viagem_volta:
            imprimir_recibo(sessao, numero_viagem_volta, True)
        else:
            print(f"Falha na compra da viagem de volta para {rota['volta']}")

    print("Processo de compra e impressão de recibo concluído.")

# Função para comprar viagem
def comprar_viagem(sessao, rota, placa, nEixos, inicioVigencia, fimVigencia, itemFin1=None, itemFin2=None, itemFin3=None):
    url = 'https://apphom.viafacil.com.br/wsvp/ValePedagio'
    headers = {
        'Content-Type': 'text/xml; charset=utf-8',
        'SOAPAction': 'comprarViagem'
    }

    envelope = etree.Element('{http://schemas.xmlsoap.org/soap/envelope/}Envelope',
                            nsmap={
                                'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
                                'xsd': 'http://www.w3.org/2001/XMLSchema',
                                'soapenv': 'http://schemas.xmlsoap.org/soap/envelope/',
                                'cgmp': 'http://cgmp.com'
                            })

    body = etree.SubElement(envelope, '{http://schemas.xmlsoap.org/soap/envelope/}Body')
    comprar_viagem = etree.SubElement(body, '{http://cgmp.com}comprarViagem',
                                    attrib={'{http://schemas.xmlsoap.org/soap/envelope/}encodingStyle': 'http://schemas.xmlsoap.org/soap/encoding/'})

    etree.SubElement(comprar_viagem, 'sessao', attrib={etree.QName('xsi', 'type'): 'xsd:long'}).text = sessao
    etree.SubElement(comprar_viagem, 'rota', attrib={etree.QName('xsi', 'type'): 'xsd:string'}).text = rota
    etree.SubElement(comprar_viagem, 'placa', attrib={etree.QName('xsi', 'type'): 'xsd:string'}).text = placa
    etree.SubElement(comprar_viagem, 'nEixos', attrib={etree.QName('xsi', 'type'): 'xsd:int'}).text = str(nEixos)
    etree.SubElement(comprar_viagem, 'inicioVigencia', attrib={etree.QName('xsi', 'type'): 'xsd:date'}).text = inicioVigencia
    etree.SubElement(comprar_viagem, 'fimVigencia', attrib={etree.QName('xsi', 'type'): 'xsd:date'}).text = fimVigencia

    if itemFin1:
        etree.SubElement(comprar_viagem, 'itemFin1', attrib={etree.QName('xsi', 'type'): 'xsd:string'}).text = itemFin1
    if itemFin2:
        etree.SubElement(comprar_viagem, 'itemFin2', attrib={etree.QName('xsi', 'type'): 'xsd:string'}).text = itemFin2
    if itemFin3:
        etree.SubElement(comprar_viagem, 'itemFin3', attrib={etree.QName('xsi', 'type'): 'xsd:string'}).text = itemFin3

    soap_request = etree.tostring(envelope, pretty_print=True, xml_declaration=True, encoding='UTF-8')

    try:
        response = requests.post(url, data=soap_request, headers=headers)
        response.raise_for_status()

        root = etree.fromstring(response.content)
        root = remove_namespaces(root)  # Remove namespaces para facilitar a busca
        numero = None
        status = None
        for element in root.iter():
            if element.tag.endswith('numero'):
                numero = element.text
            if element.tag.endswith('status'):
                status = element.text

        if status == '0':
            print(f"Compra realizada com sucesso para rota {rota}. Número da viagem: {numero}")
            return numero
        else:
            print(f"Erro na compra da viagem para rota {rota}: Código de status {status}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Erro na requisição SOAP para rota {rota}: {e}")
        return None

# Função para imprimir recibo
def imprimir_recibo(sessao, numero_viagem, imprimir_observacoes):
    url_impressao = 'https://app.viafacil.com.br/vpnew/imprimirValePedagioSTP.do'
    payload = {
        'sessao': sessao,
        'viagem': numero_viagem,
        'imprimirObservacoes': str(imprimir_observacoes).lower()
    }

    try:
        response = requests.post(url_impressao, data=payload)
        response.raise_for_status()
        print(f"Recibo da viagem {numero_viagem} foi impresso com sucesso.")
    except requests.exceptions.RequestException as e:
        print(f"Erro ao imprimir o recibo para a viagem {numero_viagem}: {e}")

# Função para processar o vale-pedágio
def preencher_vale_pedagio(equipamento, projeto, tipo_conjunto):
    # Aqui, você pode chamar a função `processar_viagem` que já foi definida no código anterior.
    # Estou assumindo que a variável `sessao`, a rota, a placa e o conjunto são os parâmetros que você vai passar.
    placa = equipamento  # Equipamento no caso é a placa do caminhão
    fazenda = projeto     # Projeto no caso é a fazenda
    conjunto = tipo_conjunto  # Tipo de conjunto vindo da função anterior

    # Agora chamamos a função que processa a viagem de acordo com as informações recebidas
    processar_viagem(placa, fazenda, conjunto)

import time


# Função para capturar as informações do site
def capturar_informacoes():
        # URL da página que você deseja acessar
    url = "https://sgf-sp.bracell.com/sgf/Modulos/Transporte/TraOrdemTransporteRodoviarioFrm.aspx?cdprocesso=48&cdfuncao=4824"

    # Cabeçalhos da requisição (mantendo os valores padrão, você pode ajustar conforme necessário)
    headers = {
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,es;q=0.6",
        "Connection": "keep-alive",
        "Host": "sgf-sp.bracell.com",
        "Referer": "https://sgf-sp.bracell.com/",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
    }

    # Cookies copiados da sua sessão
    cookies = {
        "ASP.NET_SessionId": "jzhu52kybr3vp5k2bbvzy3se",
        "{Infra.ConnectionString.Name}": "p_sgf",
        ".SGF": ""
    }

    # Fazendo a requisição GET com os cookies
    response = requests.get(url, headers=headers, cookies=cookies)

    # Verificando se a requisição foi bem-sucedida
    if response.status_code == 200:
        print("Requisição bem-sucedida!")
        # Parsear o conteúdo da página com BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Extraindo as informações desejadas
        fornecedor = soup.find('span', id="ctl48_ctl01_ctl03_CdFornecedorEquipamentoDESC").text
        projeto = soup.find('span', id="ctl48_ctl01_ctl03_CdProjetoDESC").text
        documento = soup.find('span', id="ctl48_ctl01_ctl03_CdDocumentoDESC").text
        equipamento = soup.find('span', id="ctl48_ctl01_ctl03_CdEquipamentoDESC").text
        tipo_conjunto = soup.find('span', id="ctl48_ctl01_ctl03_CdTipoConjuntoDESC").text
        situacao = soup.find('span', id="ctl48_ctl01_ctl03_TipSituacaoDESC").text

        # Exibindo as informações capturadas
        print("Fornecedor:", fornecedor)
        print("Projeto:", projeto)
        print("Documento:", documento)
        print("Equipamento:", equipamento)
        print("Tipo de Conjunto:", tipo_conjunto)
        print("Situação:", situacao)
    else:
        print(f"Erro ao acessar a página: {response.status_code}")
        

# Exemplo de chamada para testar
fornecedor, projeto, documento, equipamento, tipo_conjunto, situacao = capturar_informacoes()


# Função principal para integrar com o polling e chamar o Vale Pedágio
def preencher_vale_pedagio_com_dados(fornecedor, projeto, documento, equipamento, tipo_conjunto, situacao):
    if situacao == "Circulação":
        # Aqui chamamos a função que já existe no seu script do VP para processar a viagem
        processar_viagem(equipamento, projeto, tipo_conjunto)  # Essa função já deve estar implementada no seu VP
    elif situacao == "Gerada":
        print(f"Situação {situacao}. Aguardando processamento futuro.")
    elif situacao == "Finalizada":
        print(f"Situação {situacao}. Descartando a viagem.")


# Função que verifica as informações periodicamente e dispara o VP
def verificar_periodicamente():
    while True:
        fornecedor, projeto, documento, equipamento, tipo_conjunto, situacao = capturar_informacoes()
        
        if fornecedor and projeto and documento and equipamento and tipo_conjunto and situacao:
            print(f"Informações capturadas: Fornecedor: {fornecedor}, Projeto: {projeto}, Documento: {documento}, Equipamento: {equipamento}, Conjunto: {tipo_conjunto}, Situação: {situacao}")
            preencher_vale_pedagio_com_dados(fornecedor, projeto, documento, equipamento, tipo_conjunto, situacao)
        else:
            print("Não foi possível capturar as informações do site.")
        
        time.sleep(120)  # Espera por 10 minutos antes de fazer uma nova verificação


# ---- Chamada principal do sistema ----
# Iniciar a verificação periódica e o processo do Vale Pedágio
verificar_periodicamente()
# Out:
# Requisição bem-sucedida!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 255
#     251         print(f"Erro ao acessar a página: {response.status_code}")
#     254 # Exemplo de chamada para testar
# --> 255 fornecedor, projeto, documento, equipamento, tipo_conjunto, situacao = capturar_informacoes()
#     258 # Função principal para integrar com o polling e chamar o Vale Pedágio
#     259 def preencher_vale_pedagio_com_dados(fornecedor, projeto, documento, equipamento, tipo_conjunto, situacao):
#
# Cell In[2], line 236, in capturar_informacoes()
#     233 soup = BeautifulSoup(response.text, 'html.parser')
#     235 # Extraindo as informações desejadas
# --> 236 fornecedor = soup.find('span', id="ctl48_ctl01_ctl03_CdFornecedorEquipamentoDESC").text
#     237 projeto = soup.find('span', id="ctl48_ctl01_ctl03_CdProjetoDESC").text
# ...

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
from lxml import etree

# ---- Listas de placas para 5 e 6 eixos ----
placas_5_eixos = ["PLACA1", "PLACA2", "PLACA3"]  # Substitua com as placas reais
placas_6_eixos = ["PLACA4", "PLACA5", "PLACA6"]  # Substitua com as placas reais

# Função para capturar as informações em múltiplas linhas
def capturar_informacoes():
    url = "https://sgf-sp.bracell.com/sgf/Modulos/Transporte/TraOrdemTransporteRodoviarioFrm.aspx?cdprocesso=4&cdfuncao=4824"
    
    headers = {
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
        "Accept-Encoding": "gzip, deflate, br, zstd",
        "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,es;q=0.6",
        "Connection": "keep-alive",
        "Referer": "https://sgf-sp.bracell.com/",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
    }

    cookies = {
        "ASP.NET_SessionId": "bpboxa0jcy5trg1v1ey0otz2",
        "{Infra.ConnectionString.Name}": "p_sgf",
        ".SGF": ""
    }

    # Fazendo a requisição GET com os cookies
    response = requests.get(url, headers=headers, cookies=cookies)

    # Verificando se a requisição foi bem-sucedida
    if response.status_code == 200:
        print("Requisição bem-sucedida!")
        # Parsear o conteúdo da página com BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Loop para capturar informações de várias linhas (ctl03 a ctl12)
        for i in range(3, 13):  # ctl03 até ctl12
            try:
                fornecedor = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdFornecedorEquipamentoDESC")
                projeto = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdProjetoDESC")
                documento = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdDocumentoDESC")
                equipamento = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdEquipamentoDESC")
                tipo_conjunto = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdTipoConjuntoDESC")
                situacao = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_TipSituacaoDESC")

                # Verificar se todos os elementos foram encontrados
                if not all([fornecedor, projeto, documento, equipamento, tipo_conjunto, situacao]):
                    print(f"Linha {i-2}: Informações incompletas, alguns elementos não foram encontrados.")
                    print("-" * 50)
                    continue

                fornecedor = fornecedor.text
                projeto = projeto.text
                documento = documento.text
                equipamento = equipamento.text
                tipo_conjunto = tipo_conjunto.text.strip().lower()  # Normaliza o valor para letras minúsculas
                situacao = situacao.text

                # Lógica de filtragem de projetos e fornecedores
                if projeto in ["SÃO MANOEL GLEBA A - CPG", "SANTO ANTÔNIO", "NOSSA SENHORA APARECIDA XV"]:
                    print(f"Linha {i-2}: Projeto '{projeto}' ignorado.")
                    continue

                # Definir o número de eixos com base no tipo de conjunto
                if fornecedor == "CARGO POLO COMERCIO, LOGISTICA E TRANSPORTE":
                    if equipamento in placas_5_eixos:
                        tipo_conjunto = "cargo polo (5 eixos ida)"
                    elif equipamento in placas_6_eixos:
                        tipo_conjunto = "cargo polo (6 eixos ida)"
                    else:
                        print(f"Linha {i-2}: Placa {equipamento} não reconhecida nas listas de 5 ou 6 eixos. Ignorado.")
                        continue

                # Logica para decisão baseada na situação
                if situacao == "Circulacao":
                    print(f"Linha {i-2}: Preencher Vale-Pedágio")
                    print("Fornecedor:", fornecedor)
                    print("Projeto:", projeto)
                    print("Documento:", documento)
                    print("Equipamento:", equipamento)
                    print("Tipo de Conjunto:", tipo_conjunto)
                    print("Situação:", situacao)

                    # Processar a viagem de acordo com o tipo de conjunto
                    processar_viagem(equipamento, projeto, tipo_conjunto)
                    print("-" * 50)

                elif situacao == "Gerada":
                    print(f"Linha {i-2}: Situação GERADA, tentar novamente na próxima iteração.")
                    print("-" * 50)
                
                elif situacao == "Finalizada":
                    print(f"Linha {i-2}: Situação FINALIZADA, descartando este caminhão.")
                    print("-" * 50)

            except AttributeError as e:
                print(f"Linha {i-2}: Erro ao capturar informações: {e}")
                print("-" * 50)
    else:
        print(f"Erro ao acessar a página: {response.status_code}")

# Função para autenticar o usuário no sistema de Vale-Pedágio
def autenticar_usuario():
    url = 'https://apphom.viafacil.com.br/wsvp/ValePedagio'
    headers = {
        'Content-Type': 'text/xml; charset=utf-8',
        'SOAPAction': 'autenticarUsuario'
    }
    envelope = etree.Element('{http://schemas.xmlsoap.org/soap/envelope/}Envelope',
                            nsmap={
                                'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
                                'xsd': 'http://www.w3.org/2001/XMLSchema',
                                'soapenv': 'http://schemas.xmlsoap.org/soap/envelope/',
                                'cgmp': 'http://cgmp.com'
                            })
    body = etree.SubElement(envelope, '{http://schemas.xmlsoap.org/soap/envelope/}Body')
    autenticar_usuario = etree.SubElement(body, '{http://cgmp.com}autenticarUsuario',
                                        attrib={'{http://schemas.xmlsoap.org/soap/envelope/}encodingStyle': 'http://schemas.xmlsoap.org/soap/encoding/'})
    
    codigodeacesso = etree.SubElement(autenticar_usuario, 'codigodeacesso', attrib={etree.QName('xsi', 'type'): 'xsd:string'})
    codigodeacesso.text = '53943098000187'
    
    login = etree.SubElement(autenticar_usuario, 'login', attrib={etree.QName('xsi', 'type'): 'xsd:string'})
    login.text = 'ADMINISTRADOR'
    
    senha = etree.SubElement(autenticar_usuario, 'senha', attrib={etree.QName('xsi', 'type'): 'xsd:string'})
    senha.text = 'grupostp'
    
    soap_request = etree.tostring(envelope, pretty_print=True, xml_declaration=True, encoding='UTF-8')
    
    try:
        response = requests.post(url, data=soap_request, headers=headers)
        response.raise_for_status()

        response_content = etree.fromstring(response.content)
        response_content = remove_namespaces(response_content)

        autenticar_usuario_return = response_content.find('.//autenticarUsuarioReturn')
        if autenticar_usuario_return is not None:
            sessao_element = autenticar_usuario_return.find('.//sessao')
            if sessao_element is not None:
                return sessao_element.text
        return None
    except requests.exceptions.RequestException as e:
        print(f"Erro na requisição SOAP: {e}")
        return None

# Função para processar a viagem
def processar_viagem(placa, fazenda, conjunto):
    # Autentica o usuário e obtém a sessão
    sessao = autenticar_usuario()
    if not sessao:
        print("Erro ao autenticar o usuário. Verifique as credenciais e tente novamente.")
        return

    # Definir as datas de vigência
    inicio_vigencia = datetime.today().strftime('%Y-%m-%d')
    fim_vigencia = (datetime.today() + timedelta(days=5)).strftime('%Y-%m-%d')

    # Definir os eixos com base no tipo de conjunto
    conjunto = conjunto.lower()  # Normaliza o valor para minúsculas
    if conjunto == 'bitrem':
        n_eixos_ida = 4
        n_eixos_volta = 7
    elif conjunto == 'tritrem':
        n_eixos_ida = 6
        n_eixos_volta = 9
    elif conjunto == 'cargo polo (5 eixos ida)':
        n_eixos_ida = 5
        n_eixos_volta = 9
    elif conjunto == 'cargo polo (6 eixos ida)':
        n_eixos_ida = 6
        n_eixos_volta = 9
    else:
        print("Tipo de conjunto não reconhecido.")
        return

    # Chamando a função para comprar a viagem e imprimir recibo
    rota_ida = f'FAZ {fazenda} - IDA'
    rota_volta = f'FAZ {fazenda} - VOLTA'

    numero_viagem_ida = comprar_viagem(sessao, rota_ida, placa, n_eixos_ida, inicio_vigencia, fim_vigencia)
    if numero_viagem_ida:
        imprimir_recibo(sessao, numero_viagem_ida, True)
    else:
        print(f"Falha na compra da viagem de ida para {rota_ida}")

    numero_viagem_volta = comprar_viagem(sessao, rota_volta, placa, n_eixos_volta, inicio_vigencia, fim_vigencia)
    if numero_viagem_volta:
        imprimir_recibo(sessao, numero_viagem_volta, True)
    else:
        print(f"Falha na compra da viagem de volta para {rota_volta}")

    print("Processo de compra e impressão de recibo concluído.")

# Função para comprar viagem
def comprar_viagem(sessao, rota, placa, n_eixos, inicio_vigencia, fim_vigencia):
    url = 'https://apphom.viafacil.com.br/wsvp/ValePedagio'
    headers = {
        'Content-Type': 'text/xml; charset=utf-8',
        'SOAPAction': 'comprarViagem'
    }

    envelope = etree.Element('{http://schemas.xmlsoap.org/soap/envelope/}Envelope',
                            nsmap={
                                'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
                                'xsd': 'http://www.w3.org/2001/XMLSchema',
                                'soapenv': 'http://schemas.xmlsoap.org/soap/envelope/',
                                'cgmp': 'http://cgmp.com'
                            })

    body = etree.SubElement(envelope, '{http://schemas.xmlsoap.org/soap/envelope/}Body')
    comprar_viagem = etree.SubElement(body, '{http://cgmp.com}comprarViagem',
                                    attrib={'{http://schemas.xmlsoap.org/soap/envelope/}encodingStyle': 'http://schemas.xmlsoap.org/soap/encoding/'})

    etree.SubElement(comprar_viagem, 'sessao', attrib={etree.QName('xsi', 'type'): 'xsd:long'}).text = sessao
    etree.SubElement(comprar_viagem, 'rota', attrib={etree.QName('xsi', 'type'): 'xsd:string'}).text = rota
    etree.SubElement(comprar_viagem, 'placa', attrib={etree.QName('xsi', 'type'): 'xsd:string'}).text = placa
    etree.SubElement(comprar_viagem, 'nEixos', attrib={etree.QName('xsi', 'type'): 'xsd:int'}).text = str(n_eixos)
    etree.SubElement(comprar_viagem, 'inicioVigencia', attrib={etree.QName('xsi', 'type'): 'xsd:date'}).text = inicio_vigencia
    etree.SubElement(comprar_viagem, 'fimVigencia', attrib={etree.QName('xsi', 'type'): 'xsd:date'}).text = fim_vigencia

    soap_request = etree.tostring(envelope, pretty_print=True, xml_declaration=True, encoding='UTF-8')

    try:
        response = requests.post(url, data=soap_request, headers=headers)
        response.raise_for_status()

        root = etree.fromstring(response.content)
        root = remove_namespaces(root)

        numero = None
        status = None
        for element in root.iter():
            if element.tag.endswith('numero'):
                numero = element.text
            if element.tag.endswith('status'):
                status = element.text

        if status == '0':
            print(f"Compra realizada com sucesso para rota {rota}. Número da viagem: {numero}")
            return numero
        else:
            print(f"Erro na compra da viagem para rota {rota}: Código de status {status}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Erro na requisição SOAP para rota {rota}: {e}")
        return None

# Função para imprimir recibo
def imprimir_recibo(sessao, numero_viagem, imprimir_observacoes):
    url_impressao = 'https://app.viafacil.com.br/vpnew/imprimirValePedagioSTP.do'
    payload = {
        'sessao': sessao,
        'viagem': numero_viagem,
        'imprimirObservacoes': str(imprimir_observacoes).lower()
    }

    try:
        response = requests.post(url_impressao, data=payload)
        response.raise_for_status()
        print(f"Recibo da viagem {numero_viagem} foi impresso com sucesso.")
    except requests.exceptions.RequestException as e:
        print(f"Erro ao imprimir o recibo para a viagem {numero_viagem}: {e}")

# Executar a função de captura de informações
capturar_informacoes()
# Out:
# Requisição bem-sucedida!
# Linha 1: Informações incompletas, alguns elementos não foram encontrados.
# --------------------------------------------------
# Linha 2: Informações incompletas, alguns elementos não foram encontrados.
# --------------------------------------------------
# Linha 3: Informações incompletas, alguns elementos não foram encontrados.
# --------------------------------------------------
# Linha 4: Informações incompletas, alguns elementos não foram encontrados.
# --------------------------------------------------
# Linha 5: Informações incompletas, alguns elementos não foram encontrados.
# --------------------------------------------------
# Linha 6: Informações incompletas, alguns elementos não foram encontrados.
# --------------------------------------------------
# Linha 7: Informações incompletas, alguns elementos não foram encontrados.
# --------------------------------------------------
# ...

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
from lxml import etree
import json
import os
import time

# Caminho do arquivo JSON para armazenar compras realizadas
ARQUIVO_COMPRAS = 'compras_realizadas.json'

# Função para carregar compras realizadas do arquivo JSON
def carregar_compras_realizadas():
    if os.path.exists(ARQUIVO_COMPRAS):
        with open(ARQUIVO_COMPRAS, 'r') as f:
            return json.load(f)
    return {}

# Função para salvar compras realizadas no arquivo JSON
def salvar_compras_realizadas(compras):
    with open(ARQUIVO_COMPRAS, 'w') as f:
        json.dump(compras, f, indent=4)

# Função para verificar se a viagem já foi comprada com base no número do documento
def viagem_ja_comprada(documento):
    compras_realizadas = carregar_compras_realizadas()
    return documento in compras_realizadas

# Função para registrar a compra realizada
def registrar_compra_realizada(documento):
    compras_realizadas = carregar_compras_realizadas()
    compras_realizadas[documento] = True  # Marca o documento como já processado
    salvar_compras_realizadas(compras_realizadas)


# Função para capturar as informações e evitar compras repetidas
def capturar_informacoes():
    url = "https://sgf-sp.bracell.com/sgf/Modulos/Transporte/TraOrdemTransporteRodoviarioFrm.aspx?cdprocesso=4&cdfuncao=4824"
    
    headers = {
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
        "Accept-Encoding": "gzip, deflate, br, zstd",
        "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,es;q=0.6",
        "Connection": "keep-alive",
        "Referer": "https://sgf-sp.bracell.com/",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
    }

    cookies = {
        "ASP.NET_SessionId": "a4bgcbtven4omf3encb2mrnx",
        "{Infra.ConnectionString.Name}": "p_sgf",
        ".SGF": ""
   
    }

    # Fazendo a requisição GET com os cookies
    response = requests.get(url, headers=headers, cookies=cookies)

    # Verificando se a requisição foi bem-sucedida
    if response.status_code == 200:
        print("Requisição bem-sucedida!")
        soup = BeautifulSoup(response.text, 'html.parser')



        # Loop para capturar informações de várias linhas (ctl03 a ctl12)
        for i in range(3, 10 ):  # ctl03 até ctl12
            try:
                fornecedor = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdFornecedorEquipamentoDESC")
                projeto = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdProjetoDESC")
                documento = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdDocumentoDESC")
                equipamento = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdEquipamentoDESC")
                tipo_conjunto = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_CdTipoConjuntoDESC")
                situacao = soup.find('span', id=f"ctl48_ctl01_ctl{i:02}_TipSituacaoDESC")

                # Verificar se todos os elementos foram encontrados
                if not all([fornecedor, projeto, documento, equipamento, tipo_conjunto, situacao]):
                    print(f"Linha {i-2}: Informações incompletas, alguns elementos não foram encontrados.")
                    print("-" * 50)
                    continue

                fornecedor = fornecedor.text
                projeto = projeto.text
                documento = documento.text
                equipamento = equipamento.text
                tipo_conjunto = tipo_conjunto.text.strip().lower()
                situacao = situacao.text

                # Lógica para evitar projetos ignorados
                if projeto in ["SÃO MANOEL GLEBA A - CPG", "SANTO ANTÔNIO", "NOSSA SENHORA APARECIDA XV"]:
                    print(f"Linha {i-2}: Projeto '{projeto}' ignorado.")
                    continue

                # Verificação de compra repetida
                if viagem_ja_comprada(documento):
                    print(f"Linha {i-2}: Viagem com documento {documento} e placa {equipamento} já foi comprada anteriormente. Ignorando.")
                    continue

                # Verificação para circulacao
                if situacao == "Circulacao":
                    print(f"Linha {i-2}: Preencher Vale-Pedágio")
                    print("Fornecedor:", fornecedor)
                    print("Projeto:", projeto)
                    print("Documento:", documento)
                    print("Equipamento:", equipamento)
                    print("Tipo de Conjunto:", tipo_conjunto)
                    print("Situação:", situacao)

                    # Processar a viagem de acordo com o tipo de conjunto
                    processar_viagem(equipamento, projeto, tipo_conjunto)

                    # Registrar a compra para evitar repetição futura
                    registrar_compra_realizada(documento)
                    print("-" * 50)

                elif situacao == "Gerada":
                    print(f"Linha {i-2}: Situação GERADA, tentar novamente na próxima iteração.")
                    print("-" * 50)
                
                elif situacao == "Finalizada":
                    print(f"Linha {i-2}: Situação FINALIZADA, descartando este caminhão.")
                    print("-" * 50)

            except AttributeError as e:
                print(f"Linha {i-2}: Erro ao capturar informações: {e}")
                print("-" * 50)
    else:
        print(f"Erro ao acessar a página: {response.status_code}")

# Função para autenticar o usuário no sistema de Vale-Pedágio (mesma função de antes)
# Funções processar_viagem, comprar_viagem e imprimir_recibo (mesmas funções de antes)

# Função para remover namespaces do XML
def remove_namespaces(tree):
    """Remove namespaces de um elemento XML e seus filhos."""
    for elem in tree.getiterator():
        elem.tag = elem.tag.split('}')[-1]
    etree.cleanup_namespaces(tree)
    return tree


# Função para autenticar o usuário no sistema de Vale-Pedágio
def autenticar_usuario():
    url = 'https://apphom.viafacil.com.br/wsvp/ValePedagio'
    headers = {
        'Content-Type': 'text/xml; charset=utf-8',
        'SOAPAction': 'autenticarUsuario'
    }
    envelope = etree.Element('{http://schemas.xmlsoap.org/soap/envelope/}Envelope',
                            nsmap={
                                'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
                                'xsd': 'http://www.w3.org/2001/XMLSchema',
                                'soapenv': 'http://schemas.xmlsoap.org/soap/envelope/',
                                'cgmp': 'http://cgmp.com'
                            })
    body = etree.SubElement(envelope, '{http://schemas.xmlsoap.org/soap/envelope/}Body')
    autenticar_usuario = etree.SubElement(body, '{http://cgmp.com}autenticarUsuario',
                                        attrib={'{http://schemas.xmlsoap.org/soap/envelope/}encodingStyle': 'http://schemas.xmlsoap.org/soap/encoding/'})
    
    codigodeacesso = etree.SubElement(autenticar_usuario, 'codigodeacesso', attrib={etree.QName('xsi', 'type'): 'xsd:string'})
    codigodeacesso.text = '53943098000187'
    
    login = etree.SubElement(autenticar_usuario, 'login', attrib={etree.QName('xsi', 'type'): 'xsd:string'})
    login.text = 'ADMINISTRADOR'
    
    senha = etree.SubElement(autenticar_usuario, 'senha', attrib={etree.QName('xsi', 'type'): 'xsd:string'})
    senha.text = 'grupostp'
    
    soap_request = etree.tostring(envelope, pretty_print=True, xml_declaration=True, encoding='UTF-8')
    
    try:
        response = requests.post(url, data=soap_request, headers=headers)
        response.raise_for_status()

        response_content = etree.fromstring(response.content)
        response_content = remove_namespaces(response_content)

        autenticar_usuario_return = response_content.find('.//autenticarUsuarioReturn')
        if autenticar_usuario_return is not None:
            sessao_element = autenticar_usuario_return.find('.//sessao')
            if sessao_element is not None:
                return sessao_element.text
        return None
    except requests.exceptions.RequestException as e:
        print(f"Erro na requisição SOAP: {e}")
        return None

# Função para processar a viagem
def processar_viagem(placa, fazenda, conjunto):
    # Autentica o usuário e obtém a sessão
    sessao = autenticar_usuario()
    if not sessao:
        print("Erro ao autenticar o usuário. Verifique as credenciais e tente novamente.")
        return

    # Definir as datas de vigência
    inicio_vigencia = datetime.today().strftime('%Y-%m-%d')
    fim_vigencia = (datetime.today() + timedelta(days=5)).strftime('%Y-%m-%d')

    # Definir os eixos com base no tipo de conjunto
    conjunto = conjunto.lower()  # Normaliza o valor para minúsculas
    if conjunto == 'bitrem':
        n_eixos_ida = 4
        n_eixos_volta = 7
    elif conjunto == 'tritrem':
        n_eixos_ida = 6
        n_eixos_volta = 9
    elif conjunto == 'cargo polo (5 eixos ida)':
        n_eixos_ida = 5
        n_eixos_volta = 9
    elif conjunto == 'cargo polo (6 eixos ida)':
        n_eixos_ida = 6
        n_eixos_volta = 9
    else:
        print("Tipo de conjunto não reconhecido.")
        return

    # Chamando a função para comprar a viagem e imprimir recibo
    rota_ida = f'FAZ {fazenda} - IDA'
    rota_volta = f'FAZ {fazenda} - VOLTA'

    numero_viagem_ida = comprar_viagem(sessao, rota_ida, placa, n_eixos_ida, inicio_vigencia, fim_vigencia)
    if numero_viagem_ida:
        imprimir_recibo(sessao, numero_viagem_ida, True)
    else:
        print(f"Falha na compra da viagem de ida para {rota_ida}")

    numero_viagem_volta = comprar_viagem(sessao, rota_volta, placa, n_eixos_volta, inicio_vigencia, fim_vigencia)
    if numero_viagem_volta:
        imprimir_recibo(sessao, numero_viagem_volta, True)
    else:
        print(f"Falha na compra da viagem de volta para {rota_volta}")

    print("Processo de compra e impressão de recibo concluído.")

# Função para comprar viagem
def comprar_viagem(sessao, rota, placa, n_eixos, inicio_vigencia, fim_vigencia):
    url = 'https://apphom.viafacil.com.br/wsvp/ValePedagio'
    headers = {
        'Content-Type': 'text/xml; charset=utf-8',
        'SOAPAction': 'comprarViagem'
    }

    envelope = etree.Element('{http://schemas.xmlsoap.org/soap/envelope/}Envelope',
                            nsmap={
                                'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
                                'xsd': 'http://www.w3.org/2001/XMLSchema',
                                'soapenv': 'http://schemas.xmlsoap.org/soap/envelope/',
                                'cgmp': 'http://cgmp.com'
                            })

    body = etree.SubElement(envelope, '{http://schemas.xmlsoap.org/soap/envelope/}Body')
    comprar_viagem = etree.SubElement(body, '{http://cgmp.com}comprarViagem',
                                    attrib={'{http://schemas.xmlsoap.org/soap/envelope/}encodingStyle': 'http://schemas.xmlsoap.org/soap/encoding/'})

    etree.SubElement(comprar_viagem, 'sessao', attrib={etree.QName('xsi', 'type'): 'xsd:long'}).text = sessao
    etree.SubElement(comprar_viagem, 'rota', attrib={etree.QName('xsi', 'type'): 'xsd:string'}).text = rota
    etree.SubElement(comprar_viagem, 'placa', attrib={etree.QName('xsi', 'type'): 'xsd:string'}).text = placa
    etree.SubElement(comprar_viagem, 'nEixos', attrib={etree.QName('xsi', 'type'): 'xsd:int'}).text = str(n_eixos)
    etree.SubElement(comprar_viagem, 'inicioVigencia', attrib={etree.QName('xsi', 'type'): 'xsd:date'}).text = inicio_vigencia
    etree.SubElement(comprar_viagem, 'fimVigencia', attrib={etree.QName('xsi', 'type'): 'xsd:date'}).text = fim_vigencia

    soap_request = etree.tostring(envelope, pretty_print=True, xml_declaration=True, encoding='UTF-8')

    try:
        response = requests.post(url, data=soap_request, headers=headers)
        response.raise_for_status()

        root = etree.fromstring(response.content)
        root = remove_namespaces(root)

        numero = None
        status = None
        for element in root.iter():
            if element.tag.endswith('numero'):
                numero = element.text
            if element.tag.endswith('status'):
                status = element.text

        if status == '0':
            print(f"Compra realizada com sucesso para rota {rota}. Número da viagem: {numero}")
            return numero
        else:
            print(f"Erro na compra da viagem para rota {rota}: Código de status {status}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Erro na requisição SOAP para rota {rota}: {e}")
        return None

# Função para imprimir recibo
def imprimir_recibo(sessao, numero_viagem, imprimir_observacoes):
    url_impressao = 'https://app.viafacil.com.br/vpnew/imprimirValePedagioSTP.do'
    payload = {
        'sessao': sessao,
        'viagem': numero_viagem,
        'imprimirObservacoes': str(imprimir_observacoes).lower()
    }

    try:
        response = requests.post(url_impressao, data=payload)
        response.raise_for_status()
        print(f"Recibo da viagem {numero_viagem} foi impresso com sucesso.")
    except requests.exceptions.RequestException as e:
        print(f"Erro ao imprimir o recibo para a viagem {numero_viagem}: {e}")



# Loop infinito para rodar o script a cada 5 minutos
while True:
    capturar_informacoes()  # Executa a função principal do seu script
    time.sleep(120)  # Aguarda 300 segundos (2 minutos) antes de rodar novamente
# Out:
# Requisição bem-sucedida!
# Linha 1: Projeto 'SANTO ANTÔNIO' ignorado.
# Linha 2: Projeto 'SÃO MANOEL GLEBA A - CPG' ignorado.
# Linha 3: Projeto 'SÃO MANOEL GLEBA A - CPG' ignorado.
# Linha 4: Projeto 'NOSSA SENHORA APARECIDA XV' ignorado.
# Linha 5: Projeto 'SÃO MANOEL GLEBA A - CPG' ignorado.
# Linha 6: Viagem com documento 5418851 e placa FJF4I02 já foi comprada anteriormente. Ignorando.
# Linha 7: Viagem com documento 122817 e placa RLJ4I86 já foi comprada anteriormente. Ignorando.
# Requisição bem-sucedida!
# Linha 1: Preencher Vale-Pedágio
# Fornecedor: VDA LOGISTICA LTDA
# Projeto: CAMPO VERDE II - GLEBA A
# Documento: 122819
# Equipamento: RWO0C48
# Tipo de Conjunto: tritrem
# Situação: Circulacao
# Erro na compra da viagem para rota FAZ CAMPO VERDE II - GLEBA A - IDA: Código de status 12
# Falha na compra da viagem de ida para FAZ CAMPO VERDE II - GLEBA A - IDA
# Erro na compra da viagem para rota FAZ CAMPO VERDE II - GLEBA A - VOLTA: Código de status 12
# ...
